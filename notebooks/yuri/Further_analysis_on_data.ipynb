# %% [markdown]
# # 아마존 세일즈 데이터 EDA - 보고서 작성용

# %% [markdown]
# ## Introduction
#
# > 앞선 3주 동안 약 **1400개** 행의 소규모 데이터를 분석하며, 기본적인 통계기법과 클러스터링에 대해 파악함.
# > 이번 EDA의 목적은 2023년의 인도, 영국, 미국, 캐나다의 **대규모** 마켓 세일즈 데이터(~150만개)를 분석함에 있음.
#
# |#| Table of Contents | Finished |
# |:--|:--:|:--:|
# |1| Install Necessary Packages & Load Data | &check; |
# |2| Acknowledge Characteristics of Data | &cross;|
#
#
# &copy; 2024 Yoori Choi <it.glasschoi@gmail.com>
# * * *

# %% [markdown]
# ## 1. Install Necessary Packages & Load Data

# %%
# Requirements.txt에 적힌 패키지들이 다 설치되어 있는지 확인
import functions.check_requirements as chk
import unittest
suite = unittest.TestLoader().loadTestsFromModule(chk)
unittest.TextTestRunner().run(suite)
# Out:
# .
# forex-python is NOT installed
# pycountry is NOT installed
# simplejson is NOT installed
# ----------------------------------------------------------------------
# Ran 1 test in 0.086s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %%
# Import Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import warnings
import json

# from tqdm import tqdm_notebook
warnings.simplefilter(action='ignore')
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

# Get the full path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '../..'))

# Add the project root to sys.path
sys.path.insert(0, project_root)

# Now try to import
from functions.amazon_analysis import AmazonAnalyzer, AmazonDataframe
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
project_root
# Out:
# '/Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning'

# %%
analyzer = AmazonAnalyzer.from_config('config.json', project_root)
# Out:
# Attempting to access: /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_india.csv
# Loaded India from cache
# Successfully added dataframe: India
# Attempting to access: /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_usa.csv
# Loaded US from cache
# Successfully added dataframe: US
# Attempting to access: /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_uk.csv
# Loaded UK from cache
# Successfully added dataframe: UK
# Attempting to access: /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_canada.csv
# Loaded Canada from cache
# Successfully added dataframe: Canada
# Attempting to access: /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon.csv
# Loaded India_2022 from cache
# Successfully added dataframe: India_2022

# %%
if analyzer:
    print("Loaded dataframes:")
    for name, df_obj in analyzer.dataframes.items():
        try:
            print(f"- {name}: {df_obj.df.shape}")
        except Exception as e:
            print(f"- {name}: Error loading - {str(e)}")
    
    result = analyzer.compare_columns_presence()
    if result is not None:
        print(result)
    else:
        print("Failed to compare columns presence")
else:
    print("Failed to initialize analyzer from config.")
# Out:
# Loaded dataframes:
# Successfully loaded CSV from /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_india.csv
# - India: (1497145, 14)
# Successfully loaded CSV from /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_usa.csv
# - US: (1393614, 14)
# Successfully loaded CSV from /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_uk.csv
# - UK: (2222724, 11)
# Successfully loaded CSV from /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon_canada.csv
# - Canada: (1988016, 14)
# Successfully loaded CSV from /Users/yoorichoi/Documents/ds_study/Amazon_sales_machine_learning/data/amazon.csv
# - India_2022: (1465, 16)
#                       India     US     UK  Canada  India_2022
# user_name             False  False  False   False        True
# actual_price           True   True  False    True        True
# boughtInLastMonth      True   True   True    True       False
# discounted_price_KRW   True   True   True    True       False
# discount_percentage    True   True  False    True        True
# discounted_price       True   True   True    True        True
# review_id             False  False  False   False        True
# review_content        False  False  False   False        True
# user_id               False  False  False   False        True
# reviews                True   True   True    True       False
# img_link               True   True   True    True        True
# category               True   True   True    True        True
# rating_count          False  False  False   False        True
# actual_price_KRW       True   True  False    True       False
# rating                 True   True   True    True        True
# about_product         False  False  False   False        True
# isBestSeller           True   True   True    True       False
# review_title          False  False  False   False        True
# product_name           True   True   True    True        True
# product_link           True   True   True    True        True
# product_id             True   True   True    True        True

# %%
india_df = analyzer.get_dataframe("India")
us_df = analyzer.get_dataframe("US")
uk_df = analyzer.get_dataframe("UK")
canada_df = analyzer.get_dataframe("Canada")
india_2022_df = analyzer.get_dataframe("India_2022")

# %%
# analyzer.clear_cache()

# %% [markdown]
# #### 나중에 prep_functions 파일이나 amazon_analysis로 옮길 수 있는 함수들

# %%
def format_korean_number(number):
    if number == 0:
        return "0원"
    
    units = ['원', '만', '억', '조']
    result = []
    
    # 음수 체크
    is_negative = number < 0
    number = abs(number)
    
    for i, unit in enumerate(units):
        unit_value = number % 10000
        if unit_value > 0:
            if i == 0:  # '원' 단위일 때는 쉼표 포함
                result.append(f"{unit_value:,}{unit}")
            else:
                result.append(f"{unit_value}{unit}")
        number //= 10000
        if number == 0:
            break
    
    # 결과를 역순으로 조합
    final_result = ' '.join(reversed(result))
    
    # 음수면 앞에 마이너스 표시
    if is_negative:
        final_result = f"-{final_result}"
        
    return final_result

# %%
# 결과를 예쁘게 포맷팅하여 출력
def print_top_items(results):
    if isinstance(results, pd.DataFrame):
        for idx, (name, price) in enumerate(zip(results[results.columns[0]], results[results.columns[1]]), 1):
            formatted_price = format_korean_number(price)  # 이전에 만든 함수 사용
            print(f"{idx}. {name}: {formatted_price}")
    else:
        for idx, (item, count) in enumerate(results.items(), 1):
            print(f"{idx}. {item}: {count}")

# %% [markdown]
# * * *
# ## 2. Acknowledge Characteristics of Data

# %%
# Compare columns across all dataframes
presence_df = analyzer.compare_columns_presence()
presence_df
# Out:
#                       India     US     UK  Canada  India_2022
# user_name             False  False  False   False        True
# actual_price           True   True  False    True        True
# boughtInLastMonth      True   True   True    True       False
# discounted_price_KRW   True   True   True    True       False
# discount_percentage    True   True  False    True        True
# discounted_price       True   True   True    True        True
# review_id             False  False  False   False        True
# review_content        False  False  False   False        True
# user_id               False  False  False   False        True
# reviews                True   True   True    True       False
# img_link               True   True   True    True        True
# category               True   True   True    True        True
# rating_count          False  False  False   False        True
# actual_price_KRW       True   True  False    True       False
# rating                 True   True   True    True        True
# about_product         False  False  False   False        True
# isBestSeller           True   True   True    True       False
# review_title          False  False  False   False        True
# product_name           True   True   True    True        True
# product_link           True   True   True    True        True
# product_id             True   True   True    True        True

# %%
def get_common_columns_by_threshold(analyzer, min_true_count=4):
    """
    Get columns that are present (True) in at least min_true_count dataframes
    
    Parameters:
    analyzer (AmazonAnalyzer): The analyzer instance
    min_true_count (int): Minimum number of True values required (default=4)
    
    Returns:
    list: Column names that meet the threshold criteria
    """
    presence_df = analyzer.compare_columns_presence()
    if presence_df is None:
        return []
        
    # Sum True values across each row
    true_counts = presence_df.sum(axis=1)
    
    # Filter rows where count >= min_true_count
    # filtered_columns = presence_df[true_counts >= min_true_count].index.tolist()
    filtered_columns = presence_df[true_counts >= min_true_count]
    
    return filtered_columns

# %%
get_common_columns_by_threshold(analyzer, 5)
# Out:
#                   India    US    UK  Canada  India_2022
# discounted_price   True  True  True    True        True
# img_link           True  True  True    True        True
# category           True  True  True    True        True
# rating             True  True  True    True        True
# product_name       True  True  True    True        True
# product_link       True  True  True    True        True
# product_id         True  True  True    True        True

# %%
get_common_columns_by_threshold(analyzer, 4)
# Out:
#                       India    US     UK  Canada  India_2022
# actual_price           True  True  False    True        True
# boughtInLastMonth      True  True   True    True       False
# discounted_price_KRW   True  True   True    True       False
# discount_percentage    True  True  False    True        True
# discounted_price       True  True   True    True        True
# reviews                True  True   True    True       False
# img_link               True  True   True    True        True
# category               True  True   True    True        True
# rating                 True  True   True    True        True
# isBestSeller           True  True   True    True       False
# product_name           True  True   True    True        True
# product_link           True  True   True    True        True
# product_id             True  True   True    True        True

# %%
# Check if cached results exist before running analysis
cache_path = os.path.join(analyzer.cache_dir, 'category_mapping_suggestions.json')
if os.path.exists(cache_path):
    with open(cache_path, 'r') as f:
        mapping_results = json.load(f)
else:
    # Print results with customized filtering
    analyzer.print_mapping_suggestions(
        min_similarity=0.7,  # Only show matches with 70% or higher similarity
        max_suggestions=3    # Show maximum 3 suggestions per category
    )

    # Or get raw results for further processing
    mapping_results = analyzer.get_category_mapping_suggestions(batch_size=2000)
# Out:
# Mapping suggestions for India_vs_US:
#
# Vacuum and Flor Care matches:
# - Vacuum Cleaners & Floor Care (similarity: 0.79)
#
# Makeup matches:
# - Makeup (similarity: 1.00)
#
# Action camera accessories matches:
# - Mac Games & Accessories (similarity: 0.75)
# - PC Games & Accessories (similarity: 0.72)
#
# Laptop matches:
# - Laptop Bags (similarity: 0.71)
#
# Men's shirts matches:
# - Men's Shoes (similarity: 0.78)
# - Women's Shoes (similarity: 0.72)
#
# Kitchen and dining matches:
# - Kitchen & Dining (similarity: 0.88)
#
# Networking equipment matches:
# - Electrical Equipment (similarity: 0.70)
#
# Men shoes matches:
# - Men's Shoes (similarity: 0.90)
# - Women's Shoes (similarity: 0.82)
#
# Male watches matches:
# - Men's Watches (similarity: 0.80)
# - Women's Watches (similarity: 0.74)
#
# Kids shoes matches:
# - Girls' Shoes (similarity: 0.73)
#
# Diet and nutrition matches:
# - Diet & Sports Nutrition (similarity: 0.73)
#
# Men's casual shoes matches:
# - Men's Shoes (similarity: 0.76)
# - Women's Shoes (similarity: 0.71)
#
# Craft Materials matches:
# - Craft Supplies & Materials (similarity: 0.73)
#
# Computer and accessories matches:
# - Women's Accessories (similarity: 0.74)
# - Men's Accessories (similarity: 0.73)
#
# Small animal matches:
# - Small Animal Supplies (similarity: 0.73)
#
# Mobile accessory matches:
# - Tablet Accessories (similarity: 0.71)
#
# Fish and Aquatics matches:
# - Fish & Aquatic Pets (similarity: 0.78)
#
# Personal care equipment matches:
# - Personal Care Products (similarity: 0.71)
#
# Women's sunglasses matches:
# - Women's Shoes (similarity: 0.71)
# - Women's Accessories (similarity: 0.70)
#
# Watches matches:
# - Boys' Watches (similarity: 0.70)
# - Men's Watches (similarity: 0.70)
#
# Men's fashion matches:
# - Men's Shoes (similarity: 0.75)
#
# Industrial and scientist matches:
# - Industrial & Scientific (similarity: 0.81)
#
# Heating, cooling and air quality matches:
# - Heating, Cooling & Air Quality (similarity: 0.94)
#
# Office products matches:
# - Oral Care Products (similarity: 0.73)
# - Skin Care Products (similarity: 0.73)
# - Hair Care Products (similarity: 0.73)
#
# Women's handbags matches:
# - Women's Handbags (similarity: 1.00)
#
# Men's jeans matches:
# - Men's Shoes (similarity: 0.73)
#
# Women's shoes matches:
# - Women's Shoes (similarity: 1.00)
# - Men's Shoes (similarity: 0.92)
# - Women's Watches (similarity: 0.79)
#
# Domestic material matches:
# - Industrial Materials (similarity: 0.70)
#
# Cricket equipment matches:
# - Electrical Equipment (similarity: 0.76)
#
# Video camera accessories matches:
# - Video Game Consoles & Accessories (similarity: 0.74)
#
# personal Care matches:
# - Beauty & Personal Care (similarity: 0.74)
# - Personal Care Products (similarity: 0.74)
#
# Health and Personal Care matches:
# - Beauty & Personal Care (similarity: 0.78)
#
# Men's sweets matches:
# - Men's Shoes (similarity: 0.78)
# - Women's Shoes (similarity: 0.72)
#
# Men's tie matches:
# - Men's Watches (similarity: 0.73)
# - Men's Shoes (similarity: 0.70)
#
# Men's dhoti matches:
# - Men's Shoes (similarity: 0.73)
# - Men's Clothing (similarity: 0.72)
#
# Ayurveda product matches:
# - Baby Care Products (similarity: 0.71)
#
# Travel Deafs matches:
# - Travel Duffel Bags (similarity: 0.73)
# - Travel Tote Bags (similarity: 0.71)
#
# Health care devices matches:
# - Health Care Products (similarity: 0.77)
#
# Men's clothes matches:
# - Men's Clothing (similarity: 0.81)
# - Men's Watches (similarity: 0.77)
# - Women's Clothing (similarity: 0.76)
#
# Lens accessory matches:
# - Men's Accessories (similarity: 0.77)
# - Women's Accessories (similarity: 0.73)
#
# Travel accessories matches:
# - Travel Accessories (similarity: 1.00)
# - Tablet Accessories (similarity: 0.83)
# - Girls' Accessories (similarity: 0.78)
#
# Backpax matches:
# - Backpacks (similarity: 0.75)
#
# Men's formal shoes matches:
# - Men's Shoes (similarity: 0.76)
# - Women's Shoes (similarity: 0.71)
#
# Sports Nutrition - Pharmacy matches:
# - Sports Nutrition Products (similarity: 0.77)
#
# hair care matches:
# - Car Care (similarity: 0.82)
# - Hardware (similarity: 0.71)
#
# Mapping suggestions for India_vs_Canada:
#
# Vacuum and Flor Care matches:
# - Vacuums  Floor Care (similarity: 0.87)
#
# Makeup matches:
# - Makeup (similarity: 1.00)
#
# Action camera accessories matches:
# - Irons, Steamers  Accessories (similarity: 0.75)
# - Computer Accessories (similarity: 0.71)
# - Memory Card Accessories (similarity: 0.71)
#
# Men's shirts matches:
# - Men's Shoes (similarity: 0.78)
# - Women's Shoes (similarity: 0.72)
#
# Camera and photo filters matches:
# - Camera  Photo (similarity: 0.70)
#
# Kitchen and dining matches:
# - Kitchen  Dining (similarity: 0.91)
# - Handmade Kitchen  Dining (similarity: 0.71)
#
# Networking equipment matches:
# - Cycling Equipment (similarity: 0.70)
# - Electrical Equipment (similarity: 0.70)
#
# Men shoes matches:
# - Men's Shoes (similarity: 0.90)
# - Women's Shoes (similarity: 0.82)
#
# Male watches matches:
# - Men's Watches (similarity: 0.80)
# - Women's Watches (similarity: 0.74)
#
# Home decoration matches:
# - Home Décor (similarity: 0.72)
#
# Diet and nutrition matches:
# - Diet  Nutrition Products (similarity: 0.71)
#
# Men's casual shoes matches:
# - Men's Shoes (similarity: 0.76)
# - Women's Shoes (similarity: 0.71)
#
# Home and kitchen matches:
# - Home  Kitchen (similarity: 0.90)
#
# Computer and accessories matches:
# - Computer Accessories (similarity: 0.91)
# - Computer Monitor Accessories (similarity: 0.85)
# - Computer Hard Drive Accessories (similarity: 0.84)
#
# Printer matches:
# - Printers (similarity: 0.93)
#
# Kundan Jewelery matches:
# - Handmade Jewellery (similarity: 0.73)
#
# Mobile accessory matches:
# - Tablet Accessories (similarity: 0.71)
#
# Beauty matches:
# - Beauty (similarity: 1.00)
#
# Women's sunglasses matches:
# - Women's Shoes (similarity: 0.71)
# - Women's Accessories (similarity: 0.70)
#
# Watches matches:
# - Men's Watches (similarity: 0.70)
#
# Men's fashion matches:
# - Men's Shoes (similarity: 0.75)
#
# Industrial and scientist matches:
# - Industrial  Scientific (similarity: 0.83)
#
# Heating, cooling and air quality matches:
# - Heating Cooling  Air Quality (similarity: 0.93)
#
# Home Theater System matches:
# - Home Theatre Systems (similarity: 0.92)
#
# Office products matches:
# - Office Products (similarity: 1.00)
# - Skin Care Products (similarity: 0.73)
#
# Women's handbags matches:
# - Women's Handbags (similarity: 1.00)
#
# Men's jeans matches:
# - Men's Shoes (similarity: 0.73)
#
# Women's shoes matches:
# - Women's Shoes (similarity: 1.00)
# - Men's Shoes (similarity: 0.92)
# - Women's Watches (similarity: 0.79)
#
# Domestic material matches:
# - Industrial Materials (similarity: 0.70)
#
# Television matches:
# - Televisions (similarity: 0.95)
# - Televisions  Video (similarity: 0.71)
#
# Statement jewelery matches:
# - Men's Jewelry (similarity: 0.71)
#
# Camera and Photo Cleiner matches:
# - Camera  Photo (similarity: 0.70)
#
# Cricket equipment matches:
# - Electrical Equipment (similarity: 0.76)
# - Cycling Equipment (similarity: 0.71)
#
# Video camera accessories matches:
# - Memory Card Accessories (similarity: 0.77)
# - Computer Accessories (similarity: 0.73)
# - Dolls  Accessories (similarity: 0.71)
#
# personal Care matches:
# - Health  Personal Care (similarity: 0.76)
#
# Health and Personal Care matches:
# - Health  Personal Care (similarity: 0.93)
#
# Men's sweets matches:
# - Men's Shoes (similarity: 0.78)
# - Women's Shoes (similarity: 0.72)
#
# Rainved Home & Kitchen matches:
# - Home  Kitchen (similarity: 0.74)
#
# Men's tie matches:
# - Men's Watches (similarity: 0.73)
# - Men's Shoes (similarity: 0.70)
#
# Men's dhoti matches:
# - Men's Shoes (similarity: 0.73)
# - Men's Clothing (similarity: 0.72)
#
# Health care devices matches:
# - Health Care Products (similarity: 0.77)
#
# Men's clothes matches:
# - Men's Clothing (similarity: 0.81)
# - Men's Watches (similarity: 0.77)
# - Women's Clothing (similarity: 0.76)
#
# Men's innerwear matches:
# - Men's Jewelry (similarity: 0.71)
#
# Pammori card matches:
# - Memory Cards (similarity: 0.75)
#
# Luxury beauty matches:
# - Luxury Beauty (similarity: 1.00)
#
# High-Fi and Home Audio Speakers matches:
# - Home Audio Speakers (similarity: 0.76)
#
# Lens accessory matches:
# - Men's Accessories (similarity: 0.77)
# - Women's Accessories (similarity: 0.73)
# - Cables  Accessories (similarity: 0.73)
#
# Travel accessories matches:
# - TV Accessories (similarity: 0.88)
# - Tablet Accessories (similarity: 0.83)
# - Games  Accessories (similarity: 0.78)
#
# Computer accessory matches:
# - Computer Accessories (similarity: 0.89)
# - Computer Monitor Accessories (similarity: 0.74)
# - Printer Accessories (similarity: 0.70)
#
# Inner care and hygiene products matches:
# - Oral Hygiene Products (similarity: 0.73)
#
# Men's formal shoes matches:
# - Men's Shoes (similarity: 0.76)
# - Women's Shoes (similarity: 0.71)
#
# Sports supplement matches:
# - Toy Sports Equipment (similarity: 0.70)
#
# hair care matches:
# - Hair Care (similarity: 1.00)
# - Hardware (similarity: 0.71)
#
# Mapping suggestions for India_vs_India_2022:
#
# Computer and accessories matches:
# - Computers&Accessories|Tablets (similarity: 0.72)
# - Computers&Accessories|Monitors (similarity: 0.70)
#
# Mapping suggestions for US_vs_Canada:
#
# Automotive Performance Parts & Accessories matches:
# - Automotive Interior Accessories (similarity: 0.74)
# - Automotive Exterior Accessories (similarity: 0.74)
#
# Makeup matches:
# - Makeup (similarity: 1.00)
#
# Home Use Medical Supplies & Equipment matches:
# - Medical Supplies  Equipment (similarity: 0.84)
#
# Tools & Home Improvement matches:
# - Tools  Home Improvement (similarity: 0.98)
#
# Bath Products matches:
# - Bath Products (similarity: 1.00)
# - Health Care Products (similarity: 0.73)
#
# Tablet Replacement Parts matches:
# - Automotive Replacement Parts (similarity: 0.77)
#
# Baby Strollers & Accessories matches:
# - Beauty Tools  Accessories (similarity: 0.79)
# - Cables  Accessories (similarity: 0.77)
# - Dolls  Accessories (similarity: 0.74)
#
# Science Education Supplies matches:
# - Science Education Supplies (similarity: 1.00)
#
# Games & Accessories matches:
# - Games  Accessories (similarity: 0.97)
# - Cables  Accessories (similarity: 0.84)
# - Men's Accessories (similarity: 0.83)
#
# Women's Shoes matches:
# - Women's Shoes (similarity: 1.00)
# - Men's Shoes (similarity: 0.92)
# - Women's Watches (similarity: 0.79)
#
# Printmaking Supplies matches:
# - Tattooing Supplies (similarity: 0.74)
# - Building Supplies (similarity: 0.70)
# - Dishwashing Supplies (similarity: 0.70)
#
# Lab & Scientific Products matches:
# - Lab  Scientific Products (similarity: 0.98)
#
# Abrasive & Finishing Products matches:
# - Abrasive  Finishing Products (similarity: 0.98)
#
# Wii Games, Consoles & Accessories matches:
# - Games  Accessories (similarity: 0.71)
#
# Computer External Components matches:
# - Computer Components (similarity: 0.81)
#
# Oral Care Products matches:
# - Health Care Products (similarity: 0.84)
# - Vision Care Products (similarity: 0.79)
# - Skin Care Products (similarity: 0.78)
#
# Power Tools & Hand Tools matches:
# - Power Tools  Hand Tools (similarity: 0.98)
# - Power  Hand Tools (similarity: 0.83)
#
# Sports & Outdoor Play Toys matches:
# - Outdoor Play Toys (similarity: 0.79)
# - Sports  Outdoors (similarity: 0.76)
#
# Toy Vehicle Playsets matches:
# - Toy Vehicles (similarity: 0.75)
#
# Test, Measure & Inspect matches:
# - Test, Measure  Inspect (similarity: 0.98)
#
# Kids' Electronics matches:
# - Electronics (similarity: 0.79)
# - Vehicle Electronics (similarity: 0.72)
#
# Gift Wrapping Supplies matches:
# - Dishwashing Supplies (similarity: 0.71)
# - Tattooing Supplies (similarity: 0.70)
#
# Home Décor Products matches:
# - Commerical Door Products (similarity: 0.74)
# - Health Care Products (similarity: 0.72)
#
# Furniture matches:
# - Furniture (similarity: 1.00)
#
# Baby & Toddler Toys matches:
# - Baby  Toddler Toys (similarity: 0.97)
#
# Horse Supplies matches:
# - Household Supplies (similarity: 0.81)
# - Pet Supplies (similarity: 0.77)
# - Dog Supplies (similarity: 0.77)
#
# Kids' Furniture matches:
# - Furniture (similarity: 0.75)
#
# Data Storage matches:
# - Data Storage (similarity: 1.00)
#
# Women's Jewelry matches:
# - Women's Jewelry (similarity: 1.00)
# - Men's Jewelry (similarity: 0.93)
#
# Women's Accessories matches:
# - Women's Accessories (similarity: 1.00)
# - Men's Accessories (similarity: 0.94)
# - Games  Accessories (similarity: 0.81)
#
# Filtration matches:
# - Filtration (similarity: 1.00)
#
# RV Parts & Accessories matches:
# - RV Parts  Accessories (similarity: 0.98)
# - Games  Accessories (similarity: 0.75)
# - Cables  Accessories (similarity: 0.73)
#
# Toys & Games matches:
# - Toys  Games (similarity: 0.96)
#
# Camera & Photo matches:
# - Camera  Photo (similarity: 0.96)
#
# Video Projectors matches:
# - Television Projectors (similarity: 0.76)
#
# Automotive Replacement Parts matches:
# - Automotive Replacement Parts (similarity: 1.00)
#
# Electrical Equipment matches:
# - Electrical Equipment (similarity: 1.00)
#
# Mac Games & Accessories matches:
# - Games  Accessories (similarity: 0.88)
# - Cables  Accessories (similarity: 0.76)
# - Mailboxes  Accessories (similarity: 0.76)
#
# PC Games & Accessories matches:
# - Games  Accessories (similarity: 0.90)
# - Cables  Accessories (similarity: 0.83)
# - Men's Accessories (similarity: 0.77)
#
# Automotive Tools & Equipment matches:
# - Automotive Tools  Equipment (similarity: 0.98)
#
# Boys' Accessories matches:
# - Dolls  Accessories (similarity: 0.80)
# - Women's Accessories (similarity: 0.78)
# - Cables  Accessories (similarity: 0.78)
#
# Travel Accessories matches:
# - TV Accessories (similarity: 0.88)
# - Tablet Accessories (similarity: 0.83)
# - Games  Accessories (similarity: 0.78)
#
# Boys' Jewelry matches:
# - Women's Jewelry (similarity: 0.71)
#
# Oils & Fluids matches:
# - Oils  Fluids (similarity: 0.96)
#
# Small Animal Supplies matches:
# - Small Appliances (similarity: 0.70)
#
# Automotive Tires & Wheels matches:
# - Automotive Tires  Wheels (similarity: 0.98)
#
# Industrial Hardware matches:
# - Industrial Hardware (similarity: 1.00)
# - Industrial Materials (similarity: 0.72)
# - Window Hardware (similarity: 0.71)
#
# Power Transmission Products matches:
# - Power Transmission Products (similarity: 1.00)
#
# Food Service Equipment & Supplies matches:
# - Food Service Equipment  Supplies (similarity: 0.98)
#
# Shaving & Hair Removal Products matches:
# - Shaving  Hair Removal Products (similarity: 0.98)
#
# Industrial Materials matches:
# - Industrial Materials (similarity: 1.00)
#
# Industrial & Scientific matches:
# - Industrial  Scientific (similarity: 0.98)
#
# Women's Watches matches:
# - Women's Watches (similarity: 1.00)
# - Men's Watches (similarity: 0.93)
# - Women's Shoes (similarity: 0.79)
#
# eBook Readers & Accessories matches:
# - Irons, Steamers  Accessories (similarity: 0.73)
#
# Vacuum Cleaners & Floor Care matches:
# - Vacuums  Floor Care (similarity: 0.81)
#
# Women's Clothing matches:
# - Women's Clothing (similarity: 1.00)
# - Men's Clothing (similarity: 0.93)
#
# Toilet Training Products matches:
# - Diet  Nutrition Products (similarity: 0.71)
#
# Child Safety Car Seats & Accessories matches:
# - Child Safety Car Seats (similarity: 0.76)
#
# Professional Dental Supplies matches:
# - Professional Medical Supplies (similarity: 0.88)
#
# Professional Medical Supplies matches:
# - Professional Medical Supplies (similarity: 1.00)
#
# Janitorial & Sanitation Supplies matches:
# - Janitorial  Sanitation Supplies (similarity: 0.98)
#
# Office Electronics matches:
# - Vehicle Electronics (similarity: 0.81)
# - Electronics (similarity: 0.76)
#
# Needlework Supplies matches:
# - Dog Supplies (similarity: 0.71)
#
# Beauty & Personal Care matches:
# - Health  Personal Care (similarity: 0.84)
#
# Arts & Crafts Supplies matches:
# - Arts  Crafts Supplies (similarity: 0.98)
#
# Pet Bird Supplies matches:
# - Pet Supplies (similarity: 0.83)
# - Building Supplies (similarity: 0.71)
#
# Ironing Products matches:
# - Networking Products (similarity: 0.74)
#
# Computer Monitors matches:
# - Computer Monitors (similarity: 1.00)
# - Computer Components (similarity: 0.78)
# - Computer Monitor Accessories (similarity: 0.76)
#
# Household Supplies matches:
# - Household Supplies (similarity: 1.00)
# - Paper  Plastic Household Supplies (similarity: 0.71)
# - Household Batteries (similarity: 0.70)
#
# Occupational Health & Safety Products matches:
# - Occupational Health  Safety Products (similarity: 0.99)
#
# Car Electronics & Accessories matches:
# - Car Electronics  Accessories (similarity: 0.98)
# - Cables  Accessories (similarity: 0.75)
#
# Heating, Cooling & Air Quality matches:
# - Heating Cooling  Air Quality (similarity: 0.97)
#
# Video Game Consoles & Accessories matches:
# - Games  Accessories (similarity: 0.71)
#
# Cell Phones & Accessories matches:
# - Cables  Accessories (similarity: 0.77)
# - Dolls  Accessories (similarity: 0.74)
# - Mailboxes  Accessories (similarity: 0.72)
#
# Cat Supplies matches:
# - Cat Supplies (similarity: 1.00)
# - Pet Supplies (similarity: 0.83)
# - Dog Supplies (similarity: 0.75)
#
# Computer Components matches:
# - Computer Components (similarity: 1.00)
# - Computer Monitors (similarity: 0.78)
#
# Stationery & Gift Wrapping Supplies matches:
# - Stationery  Party Supplies (similarity: 0.72)
#
# Hydraulics, Pneumatics & Plumbing matches:
# - Hydraulics, Pneumatics  Plumbing (similarity: 0.98)
#
# Home Appliances matches:
# - Large Appliances (similarity: 0.77)
# - Small Appliances (similarity: 0.77)
#
# Building Supplies matches:
# - Building Supplies (similarity: 1.00)
# - Dog Supplies (similarity: 0.76)
# - Dishwashing Supplies (similarity: 0.70)
#
# Baby Travel Gear matches:
# - Luggage  Travel Gear (similarity: 0.72)
#
# Sports Nutrition Products matches:
# - Diet  Nutrition Products (similarity: 0.82)
# - Power Transmission Products (similarity: 0.73)
#
# Boys' Watches matches:
# - Women's Watches (similarity: 0.71)
#
# Computers & Tablets matches:
# - Computer Cable Adapters (similarity: 0.71)
#
# Building Toys matches:
# - Building Materials (similarity: 0.71)
#
# Skin Care Products matches:
# - Skin Care Products (similarity: 1.00)
# - Vision Care Products (similarity: 0.89)
# - Health Care Products (similarity: 0.74)
#
# Sports & Outdoors matches:
# - Sports  Outdoors (similarity: 0.97)
#
# Baby & Child Care Products matches:
# - Baby  Child Care Products (similarity: 0.98)
#
# Computer Networking matches:
# - Computer Monitors (similarity: 0.72)
#
# Hair Care Products matches:
# - Health Care Products (similarity: 0.84)
# - Skin Care Products (similarity: 0.83)
# - Vision Care Products (similarity: 0.79)
#
# Laptop Accessories matches:
# - TV Accessories (similarity: 0.81)
# - Tablet Accessories (similarity: 0.78)
# - Printer Accessories (similarity: 0.76)
#
# Automotive Interior Accessories matches:
# - Automotive Interior Accessories (similarity: 1.00)
# - Automotive Exterior Accessories (similarity: 0.94)
#
# Hardware matches:
# - Hardware (similarity: 1.00)
# - Barware (similarity: 0.80)
# - Gate Hardware (similarity: 0.76)
#
# Baby Care Products matches:
# - Baby  Child Care Products (similarity: 0.84)
# - Health Care Products (similarity: 0.79)
# - Skin Care Products (similarity: 0.78)
#
# Kitchen & Dining matches:
# - Kitchen  Dining (similarity: 0.97)
# - Handmade Kitchen  Dining (similarity: 0.75)
#
# Computer Servers matches:
# - Computer Security Cables (similarity: 0.70)
#
# Men's Shoes matches:
# - Men's Shoes (similarity: 1.00)
# - Women's Shoes (similarity: 0.92)
# - Men's Watches (similarity: 0.75)
#
# Personal Care Products matches:
# - Vision Care Products (similarity: 0.81)
# - Health Care Products (similarity: 0.81)
# - Skin Care Products (similarity: 0.80)
#
# Dog Supplies matches:
# - Dog Supplies (similarity: 1.00)
# - Building Supplies (similarity: 0.76)
# - Cat Supplies (similarity: 0.75)
#
# Cutting Tools matches:
# - Cutting Tools (similarity: 1.00)
#
# Nursery Furniture, Bedding & Décor matches:
# - Nursery Furniture, Bedding  Décor (similarity: 0.99)
#
# Sewing Products matches:
# - Networking Products (similarity: 0.82)
# - Bubble Blowing Products (similarity: 0.74)
# - Skin Care Products (similarity: 0.73)
#
# Vision Products matches:
# - Vision Care Products (similarity: 0.86)
# - Television Projectors (similarity: 0.72)
#
# Car Care matches:
# - Hair Care (similarity: 0.82)
#
# Commercial Door Products matches:
# - Commerical Door Products (similarity: 0.96)
#
# Men's Watches matches:
# - Men's Watches (similarity: 1.00)
# - Women's Watches (similarity: 0.93)
# - Men's Shoes (similarity: 0.75)
#
# Baby Diapering Products matches:
# - Baby  Child Care Products (similarity: 0.71)
#
# Automotive Exterior Accessories matches:
# - Automotive Exterior Accessories (similarity: 1.00)
# - Automotive Interior Accessories (similarity: 0.94)
#
# Household Cleaning Supplies matches:
# - Household Cleaning (similarity: 0.80)
# - Household Supplies (similarity: 0.80)
# - Household Cleaning Tools (similarity: 0.78)
#
# Men's Accessories matches:
# - Men's Accessories (similarity: 1.00)
# - Women's Accessories (similarity: 0.94)
# - Games  Accessories (similarity: 0.86)
#
# Computers matches:
# - Laptop Computers (similarity: 0.72)
#
# Kitchen & Bath Fixtures matches:
# - Kitchen  Bath Fixtures (similarity: 0.98)
#
# Fasteners matches:
# - Fasteners (similarity: 1.00)
#
# Kids' Play Trains & Trams matches:
# - Kids' Play Tents  Tunnels (similarity: 0.72)
#
# Bedding matches:
# - Bedding (similarity: 1.00)
#
# Baby Safety Products matches:
# - Bath Products (similarity: 0.73)
# - Baby  Child Care Products (similarity: 0.71)
#
# Baby matches:
# - Baby (similarity: 1.00)
#
# Girls' Accessories matches:
# - Dolls  Accessories (similarity: 0.78)
# - Games  Accessories (similarity: 0.78)
# - Printer Accessories (similarity: 0.76)
#
# Party Supplies matches:
# - Cat Supplies (similarity: 0.85)
# - Pet Supplies (similarity: 0.85)
# - Laundry Supplies (similarity: 0.80)
#
# Televisions & Video Products matches:
# - Televisions  Video (similarity: 0.78)
# - Vision Care Products (similarity: 0.71)
#
# Industrial Power & Hand Tools matches:
# - Power  Hand Tools (similarity: 0.74)
#
# Dolls & Accessories matches:
# - Dolls  Accessories (similarity: 0.97)
# - Cables  Accessories (similarity: 0.79)
# - Games  Accessories (similarity: 0.76)
#
# Health Care Products matches:
# - Health Care Products (similarity: 1.00)
# - Skin Care Products (similarity: 0.74)
# - Bath Products (similarity: 0.73)
#
# Home Storage & Organization matches:
# - Home Storage  Organization (similarity: 0.98)
# - Kitchen Storage  Organization (similarity: 0.86)
#
# Material Handling Products matches:
# - Material Handling (similarity: 0.79)
#
# Men's Clothing matches:
# - Men's Clothing (similarity: 1.00)
# - Women's Clothing (similarity: 0.93)
#
# Beauty Tools & Accessories matches:
# - Beauty Tools  Accessories (similarity: 0.98)
# - Dolls  Accessories (similarity: 0.73)
# - Cables  Accessories (similarity: 0.71)
#
# Boys' Clothing matches:
# - Women's Clothing (similarity: 0.73)
# - Men's Clothing (similarity: 0.71)
#
# Women's Handbags matches:
# - Women's Handbags (similarity: 1.00)
#
# Tablet Accessories matches:
# - Tablet Accessories (similarity: 1.00)
# - Cables  Accessories (similarity: 0.86)
# - TV Accessories (similarity: 0.81)
#
# Vehicle Electronics matches:
# - Vehicle Electronics (similarity: 1.00)
# - Electronics (similarity: 0.73)
#
# Mapping suggestions for US_vs_India_2022:
#
# Computers & Tablets matches:
# - Computers&Accessories|Tablets (similarity: 0.71)
#
# Mapping suggestions for Canada_vs_India_2022:
#
# Computer Accessories matches:
# - Computers&Accessories|Tablets (similarity: 0.78)
# - Computers&Accessories|Monitors (similarity: 0.76)

# %% [markdown]
# * * *
# ### 국가 별 데이터 파악 - (1) 미국

# %%
us_df.head(3)
# Out:
#    product_id                                       product_name   category  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...  Suitcases
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...  Suitcases
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...  Suitcases
#
#    discounted_price  actual_price  discount_percentage  rating  reviews  \
# 0            139.99          0.00                    0     4.5        0
# 1            169.99        209.99                   19     4.5        0
# 2            365.49        429.99                   15     4.6        0
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
#
#                            product_link  isBestSeller  boughtInLastMonth  \
# 0  https://www.amazon.com/dp/B014TMV5YE         False               2000
# 1  https://www.amazon.com/dp/B07GDLCQXV         False               1000
# 2  https://www.amazon.com/dp/B07XSCCZYG         False                300
#
#    discounted_price_KRW  actual_price_KRW
# 0                190722                 0
# 1                231594            286089
# 2                497942            585817

# %%
category_analysis_us = analyzer.analyze_categories('US', top_n=20)
# Out:
# === US 카테고리 분석 ===
# 총 카테고리 수: 248개
# 총 상품 수: 1,393,614개
#
# 상위 20개 카테고리:
#  1. Girls' Clothing                          28,289개 (2.03%)
#  2. Boys' Clothing                           24,165개 (1.73%)
#  3. Toys & Games                             20,657개 (1.48%)
#  4. Men's Shoes                              18,780개 (1.35%)
#  5. Women's Handbags                         18,695개 (1.34%)
#  6. Girls' Jewelry                           18,441개 (1.32%)
#  7. Men's Clothing                           17,924개 (1.29%)
#  8. Men's Accessories                        17,482개 (1.25%)
#  9. Women's Clothing                         17,281개 (1.24%)
# 10. Women's Jewelry                          16,948개 (1.22%)
# 11. Travel Accessories                       16,099개 (1.16%)
# 12. Women's Shoes                            15,102개 (1.08%)
# 13. Home Storage & Organization              15,099개 (1.08%)
# 14. Women's Accessories                      13,845개 (0.99%)
# 15. Men's Watches                            12,427개 (0.89%)
# 16. Boys' Jewelry                            10,813개 (0.78%)
# 17. Girls' Shoes                             10,443개 (0.75%)
# 18. Foot, Hand & Nail Care Products          9,451개 (0.68%)
# 19. Backpacks                                9,401개 (0.67%)
# 20. Automotive Performance Parts & Accessories 9,391개 (0.67%)
#
# 기타 카테고리: 1,072,881개 (76.99%)

# %%
analyzer.analyze_category_metrics('US', 'discounted_price_KRW')  # 카테고리별 평균 가격
# Out:
# === 카테고리별 평균 discounted_price_KRW 분석 (상위 20개) ===
#  1. Computer Servers                         212만 7,416원 (상품수: 281.0개)
#  2. Computers & Tablets                      77만 9,109원 (상품수: 7,962.0개)
#  3. Smart Home: Home Entertainment           54만 1,835원 (상품수: 154.0개)
#  4. Smart Home: Vacuums and Mops             46만 9,971원 (상품수: 50.0개)
#  5. Smart Home - Heating & Cooling           35만 6,582원 (상품수: 235.0개)
#  6. Luggage Sets                             32만 3,651원 (상품수: 144.0개)
#  7. Computer Monitors                        31만 5,491원 (상품수: 3,402.0개)
#  8. Smart Home Thermostats - Compatibility Checker 24만 8,662원 (상품수: 18.0개)
#  9. Computer External Components             23만 6,096원 (상품수: 2,366.0개)
# 10. Video Projectors                         23만 4,727원 (상품수: 787.0개)
# 11. Smart Home: Smart Locks and Entry        22만 7,556원 (상품수: 270.0개)
# 12. Camera & Photo                           22만 4,331원 (상품수: 6,016.0개)
# 13. Data Storage                             21만 9,734원 (상품수: 5,851.0개)
# 14. Smart Home: Lawn and Garden              21만 5,948원 (상품수: 66.0개)
# 15. Smart Home: New Smart Devices            21만 3,140원 (상품수: 36.0개)
# 16. Smart Home: WiFi and Networking          20만 1,493원 (상품수: 166.0개)
# 17. Virtual Reality Hardware & Accessories   19만 2,612원 (상품수: 3,867.0개)
# 18. Computers                                17만 7,160원 (상품수: 7,259.0개)
# 19. Men's Watches                            17만 3,376원 (상품수: 12,427.0개)
# 20. Suitcases                                16만 9,706원 (상품수: 906.0개)

# %%
analyzer.analyze_category_metrics('US', 'rating') # 카테고리별 평균 평점
# Out:
# === 카테고리별 평균 rating 분석 (상위 20개) ===
#  1. Gift Cards                               4.83 (상품수: 139.0개)
#  2. Health & Household                       4.57 (상품수: 714.0개)
#  3. Industrial & Scientific                  4.55 (상품수: 4,412.0개)
#  4. Household Supplies                       4.54 (상품수: 1,908.0개)
#  5. Kitchen & Dining                         4.54 (상품수: 4,864.0개)
#  6. Electrical Equipment                     4.52 (상품수: 7,820.0개)
#  7. Food Service Equipment & Supplies        4.52 (상품수: 5,896.0개)
#  8. Sports & Outdoors                        4.50 (상품수: 2,638.0개)
#  9. Power Tools & Hand Tools                 4.50 (상품수: 3,797.0개)
# 10. Electronic Components                    4.49 (상품수: 1,751.0개)
# 11. Automotive Replacement Parts             4.48 (상품수: 8,267.0개)
# 12. Home Appliances                          4.48 (상품수: 6,945.0개)
# 13. Kids' Home Store                         4.47 (상품수: 1,861.0개)
# 14. Tools & Home Improvement                 4.46 (상품수: 1,705.0개)
# 15. Industrial Power & Hand Tools            4.46 (상품수: 6,626.0개)
# 16. Craft Supplies & Materials               4.46 (상품수: 7,732.0개)
# 17. Outdoor Recreation                       4.46 (상품수: 3,532.0개)
# 18. Skin Care Products                       4.45 (상품수: 7,801.0개)
# 19. Games & Accessories                      4.45 (상품수: 7,639.0개)
# 20. Hardware                                 4.45 (상품수: 4,383.0개)

# %%
print(f"=== 할인 가격 기준 카테고리 순위 (상위 10개)  ===")

top_bestseller_cat_us = analyzer.top_items_multi_filter(
    df_name='US',
    column='category',
    sort_by='discounted_price_KRW',
    n=10
)

print_top_items(top_bestseller_cat_us)
# Out:
# === 할인 가격 기준 카테고리 순위 (상위 10개)  ===
# 1. Data Storage: 2688만 2,574원
# 2. Fabric Decorating: 2643만 517원
# 3. Computer Servers: 2243만 6,920원
# 4. Computer Servers: 1720만 6,621원
# 5. Packaging & Shipping Supplies: 1705만 7,166원
# 6. Office Electronics: 1634만 6,049원
# 7. Data Storage: 1527만 8,092원
# 8. Computer Servers: 1479만 4,400원
# 9. Data Storage: 1378만 5,013원
# 10. PlayStation 3 Games, Consoles & Accessories: 1363만 7,602원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===")

top_bestseller_us = analyzer.top_items_multi_filter(
    df_name='US',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_us)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===
# 1. Overland Storage Neoxl80 Storagelibrary Lto8 SAS: 2688만 2,574원
# 2. replicas Marinas: 2643만 517원
# 3. CISCO Systems 1 Port ATM Enhanced Oc12/Stm4 Single Mode Intermediate Reach: 2243만 6,920원
# 4. Cisco Systems 7140 Router Dual 10/100 Fe Dual Ac IP Sw: 1720만 6,621원
# 5. PARTNERS BRAND Corrugated Trash Can Plain - 40 Gallon: 1705만 7,166원
# 6. Sony VPL-XW6000ES 4K HDR Laser Home Theater Projector with Native 4K SXRD Panel, White: 1634만 6,049원
# 7. HPE MSA 2062 10GBASE-T iSCSI SFF Storage: 1527만 8,092원
# 8. CISCO Systems Catalyst 5000 Family Supervisor Iii with Enhanced Nffc Ii: 1479만 4,400원
# 9. Aruba a Hewlett Packard Enterprise company HPE 108 TB Hard Drive - 3.5" Internal - SAS (12Gb/s SAS): 1378만 5,013원
# 10. A-PS-SS72T-100, Black: 1363만 7,602원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Computers & Tablets')  ===")

# 가방 카테고리에서 할인가격이 가장 비싼 상품 10개
filters = {
    'category': 'Computers & Tablets',
    # 'isBestSeller': True  # 필터 추가/삭제 가능
}

top_bestseller_computers_us = analyzer.top_items_multi_filter(
    df_name='US',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    filters=filters,
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_computers_us)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Computers & Tablets')  ===
# 1. Toughbook Panasonic 40, FZ-40 MK1, Intel® i7-1185G7, 14” Touch, 16GB, 512GB Opal SSD, 4G LTE: 796만 3,201원
# 2. MSI Creator Z17 17" Professional Creator Laptop: Intel Core i9-12900H RTX 3080 Ti 64GB DDR5 2TB NVMe SSD, QHD+ 165hz Touch 100% DCI-P3, Thunderbolt 4 w/ PD Charging, Win 11 Pro: Lunar Gray A12UHST-046: 733만 3,705원
# 3. Razer Blade 18 Gaming Laptop: NVIDIA GeForce RTX 4090-13th Gen Intel 24-Core i9 HX CPU - QHD+ 240Hz - 64GB RAM - 2TB SSD - CNC Aluminum - Compact GaN Charger - Windows 11 - Chroma RGB: 681만 1,975원
# 4. Dell Precision 7780 Mobile Workstation - 17.3" FHD AG Display Display - Intel Core i7-13850HX 20-Core (13th Gen) - 1TB SSD - 64GB DDR5 RAM - NV RTX 5000 ADA (16GB GDDR6) - Windows 11 pro: 647만 1,389원
# 5. Cooler Master 30th Year Anniversary Cosmos Infinity Gaming PC Desktop – AMD Ryzen 9 7950X - NVIDIA GeForce RTX 4090-32GB DDR5-2TB M.2 NVMe SSD – WiFi - Windows 11 Pro: 639만 7,316원
# 6. Corsair Vengeance a8100 Series Gaming PC - Liquid Cooled AMD Ryzen 9 7950X CPU - NVIDIA GeForce RTX 4090 GPU - 4TB (2X 2TB) M.2 SSD - 64GB Dominator Platinum RGB DDR5 Memory - Black: 613만 776원
# 7. Acer Predator Orion 7000 PO7-650-UR12 Gaming Desktop | 13th Gen Intel Core i9-13900KF 24-Core | NVIDIA GeForce RTX 4090 | 32GB DDR5 | 1TB PCIe Gen4 SSD | 2TB HDD | Intel WiFi 6E | RGB Keyboard & Mouse: 613만 776원
# 8. Corsair Vengeance i8100 Series Gaming PC - Liquid Cooled Intel® Core™ i9 12900KS CPU - NVIDIA® GeForce RTX™ 4090 GPU - 4TB M.2 SSD - 64GB Dominator Platinum RGB DDR5 Memory - Black: 599만 4,536원
# 9. Dell Precision 7000 7680 16" Mobile Workstation - Full HD Plus - 1920 x 1200 - Intel Core i9 13th Gen i9-13950HX Tetracosa-core (24 Core) - 64 GB Total RAM - 1 TB SSD - Aluminum Titan Gray: 592만 6,416원
# 10. Dell Precision 7770 Mobile Workstation - 17.3" FHD AG Display Display - Intel Core i7-12850HX 16-Core (12th Gen) - 2TB+1TB SSD (3TB)- 128GB DDR5 RAM - NV RTX A3000 (12GB GDDR6) - Windows 11 pro: 579만 190원

# %% [markdown]
# * * *
# ### 국가 별 데이터 파악 - (2) 캐나다

# %%
canada_df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07CV4L6HX  Green Leaf WW3D Wonder Extension Cord Winder, ...
# 1  B09N1HGY74  8pcs Toilet Seat Bumpers Universal Toilet Repl...
# 2  B087P7538J  YaeCCC 19 Pcs Hole Saw Kit 3/4''(19mm)- 6''(15...
#
#                  category  discounted_price  actual_price  \
# 0  Industrial  Scientific             47.69          0.00
# 1  Industrial  Scientific             10.99          0.00
# 2  Industrial  Scientific             25.99         27.99
#
#    discount_percentage  rating  reviews  \
# 0                    0     4.4     2876
# 1                    0     3.8       55
# 2                    7     4.0      126
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/I/81cRe0AVC4...
# 1  https://m.media-amazon.com/images/I/512CpB-EP5...
# 2  https://m.media-amazon.com/images/I/71P+qLFDFc...
#
#                           product_link  isBestSeller  boughtInLastMonth  \
# 0  https://www.amazon.ca/dp/B07CV4L6HX         False                  0
# 1  https://www.amazon.ca/dp/B09N1HGY74         False                100
# 2  https://www.amazon.ca/dp/B087P7538J         False                 50
#
#    discounted_price_KRW  actual_price_KRW
# 0                 47217                 0
# 1                 10881                 0
# 2                 25732             27712

# %%
category_analysis_canada = analyzer.analyze_categories('Canada', top_n=20)
# Out:
# === Canada 카테고리 분석 ===
# 총 카테고리 수: 266개
# 총 상품 수: 1,988,016개
#
# 상위 20개 카테고리:
#  1. Baby                                     24,077개 (1.21%)
#  2. Luggage  Travel Gear                     22,449개 (1.13%)
#  3. Handmade Home Décor                      19,143개 (0.96%)
#  4. Handmade Kitchen  Dining                 19,074개 (0.96%)
#  5. Handmade Jewellery                       18,545개 (0.93%)
#  6. Beauty                                   18,320개 (0.92%)
#  7. Men's Jewelry                            17,969개 (0.9%)
#  8. Women's Watches                          17,386개 (0.87%)
#  9. Boys                                     17,233개 (0.87%)
# 10. Electronics                              16,393개 (0.82%)
# 11. Men's Watches                            16,385개 (0.82%)
# 12. Uniforms, Work  Safety                   16,150개 (0.81%)
# 13. Men's Shoes                              16,049개 (0.81%)
# 14. Women's Shoes                            15,964개 (0.8%)
# 15. Beauty Tools  Accessories                15,868개 (0.8%)
# 16. Men                                      15,768개 (0.79%)
# 17. Shaving  Hair Removal Products           15,702개 (0.79%)
# 18. Grocery                                  15,601개 (0.78%)
# 19. Women                                    15,576개 (0.78%)
# 20. Perfume  Cologne                         15,552개 (0.78%)
#
# 기타 카테고리: 1,638,812개 (82.43%)

# %%
analyzer.analyze_category_metrics('Canada', 'discounted_price_KRW')  # 카테고리별 평균 가격
# Out:
# === 카테고리별 평균 discounted_price_KRW 분석 (상위 20개) ===
#  1. Children's Outdoor Inflatable Bouncers  Bouncy Castles 392만 7,029원 (상품수: 8,630.0개)
#  2. Desktop Computers                        250만 3,634원 (상품수: 7,924.0개)
#  3. Laptop Computers                         145만 6,723원 (상품수: 6,947.0개)
#  4. Handmade Furniture                       128만 278원 (상품수: 2,216.0개)
#  5. Outdoor Storage  Housing                 73만 8,927원 (상품수: 7,057.0개)
#  6. Outdoor Heating  Cooling                 72만 8,889원 (상품수: 8,555.0개)
#  7. Home Audio Speakers                      65만 1,611원 (상품수: 7,060.0개)
#  8. Ladders                                  60만 8,737원 (상품수: 8,657.0개)
#  9. Material Transport Equipment             58만 9,074원 (상품수: 8,825.0개)
# 10. Salon  Spa Equipment                     55만 8,076원 (상품수: 15,417.0개)
# 11. Computer Monitors                        52만 6,511원 (상품수: 7,233.0개)
# 12. Scaffolding Equipment                    49만 3,423원 (상품수: 1,613.0개)
# 13. Smart Home                               45만 7,354원 (상품수: 434.0개)
# 14. Science Education Supplies               43만 3,451원 (상품수: 8,649.0개)
# 15. Television Projectors                    43만 3,178원 (상품수: 7,560.0개)
# 16. Blu-ray Players  Recorders               35만 8,094원 (상품수: 467.0개)
# 17. Cigarette Lighters                       33만 8,458원 (상품수: 8,147.0개)
# 18. Computer Uninterrupted Power Supply      30만 7,737원 (상품수: 7,736.0개)
# 19. Kids' Play Tents  Tunnels                25만 465원 (상품수: 3,430.0개)
# 20. Water Coolers, Filters  Cartridges       23만 7,691원 (상품수: 5,218.0개)

# %%
analyzer.analyze_category_metrics('Canada', 'rating') # 카테고리별 평균 평점
# Out:
# === 카테고리별 평균 rating 분석 (상위 20개) ===
#  1. Health  Personal Care                    4.42 (상품수: 2,213.0개)
#  2. Office Products                          4.41 (상품수: 6,787.0개)
#  3. Home  Kitchen                            4.40 (상품수: 3,484.0개)
#  4. Kitchen  Dining                          4.39 (상품수: 1,417.0개)
#  5. Tools  Home Improvement                  4.38 (상품수: 2,997.0개)
#  6. Industrial  Scientific                   4.38 (상품수: 5,277.0개)
#  7. Home Storage  Organization               4.34 (상품수: 5,798.0개)
#  8. Computer Accessories                     4.32 (상품수: 1,321.0개)
#  9. Sewing, Craft  Hobby                     4.31 (상품수: 6,398.0개)
# 10. Toys  Games                              4.29 (상품수: 5,476.0개)
# 11. Power Tools  Hand Tools                  4.29 (상품수: 2,261.0개)
# 12. Electronics                              4.27 (상품수: 16,393.0개)
# 13. Automotive                               4.25 (상품수: 3,389.0개)
# 14. Beauty                                   4.24 (상품수: 18,320.0개)
# 15. Sports  Outdoors                         4.24 (상품수: 6,653.0개)
# 16. Pet Supplies                             4.24 (상품수: 9,224.0개)
# 17. Home  Portable Audio                     4.23 (상품수: 4,307.0개)
# 18. International Food Market                4.23 (상품수: 152.0개)
# 19. Hardware                                 4.22 (상품수: 6,594.0개)
# 20. Home Textiles                            4.21 (상품수: 2,913.0개)

# %%
print(f"=== 할인 가격 기준 카테고리 순위 (상위 10개)  ===")

top_bestseller_cat_canada = analyzer.top_items_multi_filter(
    df_name='Canada',
    column='category',
    sort_by='discounted_price_KRW',
    n=10
)

print_top_items(top_bestseller_cat_canada)
# Out:
# === 할인 가격 기준 카테고리 순위 (상위 10개)  ===
# 1. Outdoor Storage  Housing: 4049만 5,049원
# 2. Outdoor Storage  Housing: 3421만 396원
# 3. Television Projectors: 3176만 2,277원
# 4. Salon  Spa Equipment: 2921만 6,782원
# 5. Television Projectors: 2773만 5,099원
# 6. Salon  Spa Equipment: 2761만 4,653원
# 7. Salon  Spa Equipment: 2723만 2,089원
# 8. Salon  Spa Equipment: 2713만 8,564원
# 9. Salon  Spa Equipment: 2670만 8,584원
# 10. Television Projectors: 2611만 5,148원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===")

top_bestseller_canada = analyzer.top_items_multi_filter(
    df_name='Canada',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_canada)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===
# 1. ECOHOUSEMART | Wooden CARPORT for 2 Vehicles & Patio Cover 24 X 24 X 16'6" | Engineered Wood, GLT | PREFABRICATED DIY: 4049만 5,049원
# 2. ECOHOUSEMART | Wooden CARPORT for 2 Vehicles & Patio Cover 20 X 22 X 16 | Engineered Wood, GLT | PREFABRICATED DIY: 3421만 396원
# 3. Panasonic Solutions Company PT-MZ16KLBU Projector/Panel: 3176만 2,277원
# 4. ZHAOLEI Zero SL-Track Full Body Massage Chair w/Voice Control Heat Roller: 2921만 6,782원
# 5. Projector Projector 1080P Home Theater Cinema 1280 * 720 Video: 2773만 5,099원
# 6. VENBER Electric Massage Chair Zero Gravity Massage Chair Electric Heating Recline Full Body Massage Chair Home Automatic Zero Gravity Massage Chair Electric: 2761만 4,653원
# 7. VENBER Electric Massage Chair Zero Gravity Electric Full Body Massage Chair Electric Professional Shiatsu Back Relaxing Rocking Portable Smart: 2723만 2,089원
# 8. VENBER Electric Massage Chair Electric Massage Chair Full Body 4D Zero Gravity Multi-Functional Latest Leather Touch Screen: 2713만 8,564원
# 9. VENBER Electric Massage Chair Full Body Type Zero Gravity Compression Pressure Blood Circulation Home Automatic Massage Chair: 2670만 8,584원
# 10. PANASONIC Solutions Company PT-MZ13KLWU Projector/Panel: 2611만 5,148원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Laptop Computers')  ===")

# 가방 카테고리에서 할인가격이 가장 비싼 상품 10개
filters = {
    'category': 'Laptop Computers',
    # 'isBestSeller': True  # 필터 추가/삭제 가능
}

top_bestseller_laptop_canada = analyzer.top_items_multi_filter(
    df_name='Canada',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    filters=filters,
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_laptop_canada)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Laptop Computers')  ===
# 1. MSI Raider GE68HX 16" QHD+ (2560 x 1600) 240Hz Gaming Laptop - 13th Gen Intel Core i9-13950HX 24-Core up to 5.50 GHz CPU, 64GB DDR5 RAM, 8TB NVMe SSD, GeForce RTX 4070 8GB GDDR6, Windows 11 Home: 854만 1,940원
# 2. ASUS ROG Zephyrus G15 Gaming & Business Laptop (AMD Ryzen 9 5900HS 8-Core, 16GB RAM, 2x4TB PCIe SSD (8TB), 15.6" 2K Quad HD (2560x1440), GeForce RTX 3080, WiFi, Bluetooth, Win 11 Pro): 809만 4,207원
# 3. Toughbook Panasonic 40, FZ-40 MK1, Intel i5-1145G7, 14” Touch, 32GB, 1TB Opal SSD, 4G LTE: 803만 9,594원
# 4. ASUS ROG Zephyrus G15 Gaming & Business Laptop (AMD Ryzen 9 5900HS 8-Core, 16GB RAM, 2x4TB PCIe SSD (8TB), 15.6" 2K Quad HD (2560x1440), GeForce RTX 3080, WiFi, Bluetooth, Win 11 Home): 787만 4,405원
# 5. Toughbook Panasonic 40, FZ-40 MK1, Intel i5-1145G7, 14” Touch, 32GB, 1TB Opal SSD: 748만 5,138원
# 6. Panasonic Toughbook 40, FZ-40 MK1, Intel® i5-1145G7, 14” Touch, 16GB, 512GB Opal SSD, 4G LTE: 707만 9,207원
# 7. SAMSUNG 85-Inch Class Neo QLED 8K QN800C Series Mini LED Quantum HDR Smart TV with Ultra Slim Design, Dolby Atmos, Object Tracking Sound+, Alexa Built-in - [QN85QN800CFXZC] [Canada Version] (2023): 673만 693원
# 8. Razer Blade 15 Gaming Laptop: NVIDIA GeForce RTX 3080 Ti - 12th Gen Intel 14-Core i9 CPU - 15.6” 4K UHD 144Hz - 32GB DDR5 RAM, 1TB PCIe SSD - Windows 11 - CNC Aluminum - Chroma RGB - Thunderbolt 4: 663만 2,673원
# 9. Razer Blade 18 Gaming Laptop: NVIDIA GeForce RTX 4090-13th Gen Intel 24-Core i9 HX CPU - QHD+ 240Hz - 32GB RAM - 1TB SSD - CNC Aluminum - Compact GaN Charger - Windows 11 - Chroma RGB - Mercury: 649만 2,811원
# 10. MSI Raider GE68HX 16" QHD+ (2560 x 1600) 240Hz Gaming Laptop - 13th Gen Intel Core i9-13950HX 24-Core up to 5.50 GHz CPU, 64GB DDR5 RAM, 1TB NVMe SSD, GeForce RTX 4070 8GB GDDR6, Windows 11 Pro: 617만 6,881원

# %% [markdown]
# * * *
# ### 국가 별 데이터 파악 - (3) 영국

# %%
uk_df.head(3)
# Out:
#    product_id                                       product_name  category  \
# 0  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...     False
# 1  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...      True
# 2  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...     False
#
#    discounted_price  rating  reviews  \
# 0             21.99     4.7    15308
# 1             23.99     4.7    98099
# 2             21.99     4.7    15308
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/I/71C3lbbeLs...
# 1  https://m.media-amazon.com/images/I/61c5rSxwP0...
# 2  https://m.media-amazon.com/images/I/61j3SEUjMJ...
#
#                              product_link  isBestSeller boughtInLastMonth  \
# 0  https://www.amazon.co.uk/dp/B09B96TG33             0    Hi-Fi Speakers
# 1  https://www.amazon.co.uk/dp/B01HTH3C8S             0    Hi-Fi Speakers
# 2  https://www.amazon.co.uk/dp/B09B8YWXDF             0    Hi-Fi Speakers
#
#    discounted_price_KRW
# 0                 39128
# 1                 42686
# 2                 39128

# %%
category_analysis = analyzer.analyze_categories('UK', top_n=20)
# Out:
# === UK 카테고리 분석 ===
# 총 카테고리 수: 2개
# 총 상품 수: 2,222,724개
#
# 상위 20개 카테고리:
#  1. 0                                        2,216,707개 (99.73%)
#  2. 1                                        6,017개 (0.27%)
#
# 기타 카테고리: 0개 (0.0%)

# %%
analyzer.analyze_category_metrics('UK', 'discounted_price_KRW')  # 카테고리별 평균 가격
# Out:
# === 카테고리별 평균 discounted_price_KRW 분석 (상위 20개) ===
#  1. 0                                        16만 8,060원 (상품수: 2,216,707.0개)
#  2. 1                                        4만 1,599원 (상품수: 6,017.0개)

# %%
analyzer.analyze_category_metrics('UK', 'rating') # 카테고리별 평균 평점
# Out:
# === 카테고리별 평균 rating 분석 (상위 20개) ===
#  1. 1                                        4.42 (상품수: 6,017.0개)
#  2. 0                                        2.03 (상품수: 2,216,707.0개)

# %%
print(f"=== 할인 가격 기준 카테고리 순위 (상위 10개)  ===")

top_bestseller_cat_uk = analyzer.top_items_multi_filter(
    df_name='UK',
    column='category',
    sort_by='discounted_price_KRW',
    n=10
)

print_top_items(top_bestseller_cat_uk)
# Out:
# === 할인 가격 기준 카테고리 순위 (상위 10개)  ===
# 1. False: 1억 7793만 5,943원
# 2. False: 1억 3834만 8,754원
# 3. False: 4390만 4,964원
# 4. False: 4178만 4,217원
# 5. False: 4080만 6,797원
# 6. False: 3914만 4,128원
# 7. False: 3914만 4,128원
# 8. False: 3819만 3,629원
# 9. False: 3819만 3,629원
# 10. False: 3819만 3,629원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===")

top_bestseller_uk = analyzer.top_items_multi_filter(
    df_name='UK',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_uk)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===
# 1. HB FBA Test Treadmill: 1억 7793만 5,943원
# 2. Générique L.A 350° - I5 11400F - RTX 3050 8G - 16GB RAM - NVME 1TB: 1억 3834만 8,754원
# 3. Abaodam decor christmas ornaments Desk Ornament Designed Storm Bottle Desktop Adornment Glass Storm Bottle Home Ornament girl dining table white globe High borosilicate glass: 4390만 4,964원
# 4. BM4445-FI1-01200R10-03-E03 Driver: 4178만 4,217원
# 5. HEDUSA Halloween 3D Holographic Fan 3D Hologram Fan Display 3D Animation Video Projector Advertising Light Led Signboard Board Transmit Picture Video For Ads Display (Size : 150cm): 4080만 6,797원
# 6. YXHUI Kids Girls Figure Skating Dress Long Sleeves Rhinestone Flowers Splice Ice Skating Roller Skating Ballet Dress,Pink-XL: 3914만 4,128원
# 7. YXHUI Kids Girls Figure Skating Dress Long Sleeves Rhinestone Flowers Splice Ice Skating Roller Skating Ballet Dress,Pink-XS: 3914만 4,128원
# 8. Outdoor Furniture Wood Porch Swing Black Brown White 22" H x 52" W x 24.5" D (Color : E) (E): 3819만 3,629원
# 9. Outdoor Furniture Wood Porch Swing Black Brown White 22" H x 52" W x 24.5" D (Color : E) (Black): 3819만 3,629원
# 10. Outdoor Furniture Wood Porch Swing Black Brown White 22" H x 52" W x 24.5" D (Color : E) (D): 3819만 3,629원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Suitcases')  ===")

# 가방 카테고리에서 할인가격이 가장 비싼 상품 10개
filters = {
    'category': 'Suitcases',
    # 'isBestSeller': True  # 필터 추가/삭제 가능
}

top_bestseller_suitcases_uk = analyzer.top_items_multi_filter(
    df_name='UK',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    filters=filters,
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_suitcases_uk)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Suitcases')  ===

# %% [markdown]
# * * *
# ### 국가 별 데이터 파악 - (4) 인도 (2023)

# %%
india_df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B08VJFZQ9S  प्लेन कैज़ुअल वियर बेसबॉल कैप पुरुषों और महिला...
# 1  B08VJFYW5Q  यूनीसेक्स कॉटन एडजस्टेबल बेसबॉल कैप (काला, फ़्...
# 2  B08VJFYVX9  प्लेन कैज़ुअल वियर बेसबॉल कैप पुरुषों और महिला...
#
#               category  discounted_price  actual_price  discount_percentage  \
# 0  Men's hats and caps             299.0         499.0                   40
# 1  Men's hats and caps             299.0         499.0                   40
# 2  Men's hats and caps             275.0         300.0                    8
#
#    rating  reviews                                           img_link  \
# 0     0.0        0  https://m.media-amazon.com/images/I/61DK1GchGF...
# 1     0.0        0  https://m.media-amazon.com/images/I/61+nwjWLUg...
# 2     0.0        0  https://m.media-amazon.com/images/I/61DK1GchGF...
#
#                           product_link  isBestSeller  boughtInLastMonth  \
# 0  https://www.amazon.in/dp/B08VJFZQ9S         False                  0
# 1  https://www.amazon.in/dp/B08VJFYW5Q         False                  0
# 2  https://www.amazon.in/dp/B08VJFYVX9         False                  0
#
#    discounted_price_KRW  actual_price_KRW
# 0                  4838              8074
# 1                  4838              8074
# 2                  4449              4854

# %%
category_analysis = analyzer.analyze_categories('India', top_n=20)
# Out:
# === India 카테고리 분석 ===
# 총 카테고리 수: 209개
# 총 상품 수: 1,497,145개
#
# 상위 20개 카테고리:
#  1. Sports, fitness and outdoor              35,357개 (2.36%)
#  2. Home and kitchen                         31,358개 (2.09%)
#  3. Men's sunglasses                         26,812개 (1.79%)
#  4. Men shoes                                26,679개 (1.78%)
#  5. Fashion jewelery                         24,353개 (1.63%)
#  6. Women's shoes                            23,296개 (1.56%)
#  7. Suitcase, check in and straw             23,194개 (1.55%)
#  8. Handbags and Purses                      20,323개 (1.36%)
#  9. Amazon fashion                           20,111개 (1.34%)
# 10. Makeup                                   19,748개 (1.32%)
# 11. Men's T-shirts and polose                18,979개 (1.27%)
# 12. Kids shoes                               18,805개 (1.26%)
# 13. Fragrance                                18,506개 (1.24%)
# 14. Accessory                                18,480개 (1.23%)
# 15. Men's innerwear                          18,078개 (1.21%)
# 16. Men's shirts                             17,534개 (1.17%)
# 17. hair care                                17,254개 (1.15%)
# 18. Women's Longer and Nightwear             17,198개 (1.15%)
# 19. Men's hats and caps                      16,823개 (1.12%)
# 20. Women's Western Wear                     16,631개 (1.11%)
#
# 기타 카테고리: 1,067,626개 (71.31%)

# %%
analyzer.analyze_category_metrics('India', 'discounted_price_KRW')  # 카테고리별 평균 가격
# Out:
# === 카테고리별 평균 discounted_price_KRW 분석 (상위 20개) ===
#  1. Digital SLR camera                       182만 9,320원 (상품수: 115.0개)
#  2. Laptop                                   122만 2,970원 (상품수: 6,837.0개)
#  3. Gamzon                                   108만 1,576원 (상품수: 112.0개)
#  4. Air conditioner                          62만 3,799원 (상품수: 146.0개)
#  5. Television                               54만 1,466원 (상품수: 597.0개)
#  6. Desktop                                  52만 7,177원 (상품수: 2,926.0개)
#  7. Dining table                             44만 6,929원 (상품수: 2,523.0개)
#  8. Refrigerator                             40만 9,138원 (상품수: 2,513.0개)
#  9. Exercise and Fitness Aerobic Training Machine 37만 950원 (상품수: 2,605.0개)
# 10. Fine art                                 33만 3,941원 (상품수: 591.0개)
# 11. Presius jewelery                         30만 6,714원 (상품수: 11,736.0개)
# 12. Washing machines and dryers              27만 6,644원 (상품수: 911.0개)
# 13. Tablet                                   24만 1,058원 (상품수: 1,212.0개)
# 14. Printer                                  21만 2,181원 (상품수: 3,649.0개)
# 15. Monitor                                  20만 7,059원 (상품수: 7,250.0개)
# 16. Running GPS Unit                         20만 4,857원 (상품수: 115.0개)
# 17. Loose jamstone and diamond               19만 6,930원 (상품수: 7,464.0개)
# 18. Amazon artisan                           17만 5,635원 (상품수: 204.0개)
# 19. Room heater                              13만 9,983원 (상품수: 66.0개)
# 20. Deep Fat Frears                          13만 9,681원 (상품수: 210.0개)

# %%
analyzer.analyze_category_metrics('India', 'rating') # 카테고리별 평균 평점
# Out:
# === 카테고리별 평균 rating 분석 (상위 20개) ===
#  1. Men's winterwear                         4.52 (상품수: 4,115.0개)
#  2. Men's clothes                            4.51 (상품수: 1,966.0개)
#  3. Women's kurtas and kurtis                4.45 (상품수: 2,033.0개)
#  4. Baby - Pharmacy                          4.41 (상품수: 99.0개)
#  5. Male watches                             4.33 (상품수: 1,093.0개)
#  6. Vacuum and Flor Care                     4.31 (상품수: 2,115.0개)
#  7. EveryD Ectailles                         4.26 (상품수: 19.0개)
#  8. Bags and backpacks                       4.22 (상품수: 7,838.0개)
#  9. Deep Fat Frears                          4.20 (상품수: 210.0개)
# 10. Grocery and Tasty Foods                  4.13 (상품수: 1,479.0개)
# 11. Sanskincare                              4.12 (상품수: 65.0개)
# 12. Sanskriti_coffi                          4.12 (상품수: 45.0개)
# 13. Sanskriti & spreads                      4.08 (상품수: 149.0개)
# 14. Room heater                              4.08 (상품수: 66.0개)
# 15. Mixer Grinders                           4.05 (상품수: 389.0개)
# 16. Sanskriti                                4.03 (상품수: 420.0개)
# 17. Sanskriti_Diares & Wipes                 4.01 (상품수: 220.0개)
# 18. Women's dresses and jumpsuits            4.00 (상품수: 4,666.0개)
# 19. Irns                                     4.00 (상품수: 677.0개)
# 20. Men's formal shirts                      4.00 (상품수: 2,759.0개)

# %%
print(f"=== 할인 가격 기준 카테고리 순위 (상위 10개)  ===")

top_bestseller_cat_india = analyzer.top_items_multi_filter(
    df_name='India',
    column='category',
    sort_by='discounted_price_KRW',
    n=10
)

print_top_items(top_bestseller_cat_india)
# Out:
# === 할인 가격 기준 카테고리 순위 (상위 10개)  ===
# 1. Boys jewelry and jewelery: 1686만 2,605원
# 2. Loose jamstone and diamond: 1626만 5,517원
# 3. Boys jewelry and jewelery: 1618만 4,773원
# 4. Loose jamstone and diamond: 1618만 1,229원
# 5. Girls' jewelry and jewelery: 1617만 9,530원
# 6. Boys jewelry and jewelery: 1594만 1,893원
# 7. Boys jewelry and jewelery: 1464만 7,233원
# 8. Accessory: 1456만 3,090원
# 9. Accessory: 1448만 2,184원
# 10. Accessory: 1312만 3,122원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===")

top_bestseller_india = analyzer.top_items_multi_filter(
    df_name='India',                       # 데이터프레임 이름
    column='product_id',              # 보여줄 컬럼
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_india)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리 무관)  ===
# 1. B0BNTQL4JW: 1686만 2,605원
# 2. B0BLYV28JP: 1626만 5,517원
# 3. B0BMVDKXPF: 1618만 4,773원
# 4. B0BD1C336T: 1618만 1,229원
# 5. B0CCP6JSPN: 1617만 9,530원
# 6. B0BMVDLL7F: 1594만 1,893원
# 7. B0BMVF3SBW: 1464만 7,233원
# 8. B0BS97VQLX: 1456만 3,090원
# 9. B0BS98RLP3: 1448만 2,184원
# 10. B0BYZ2F8SQ: 1312만 3,122원

# %%
print(f"=== 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Laptop')  ===")

# 가방 카테고리에서 할인가격이 가장 비싼 상품 10개
filters = {
    'category': 'Laptop',
    # 'isBestSeller': True  # 필터 추가/삭제 가능
}

top_bestseller_laptop_india = analyzer.top_items_multi_filter(
    df_name='India',                       # 데이터프레임 이름
    column='product_name',              # 보여줄 컬럼
    filters=filters,
    sort_by='discounted_price_KRW',     # 정렬 기준
    n=10                                # 결과 개수
)

print_top_items(top_bestseller_laptop_india)
# Out:
# === 할인 가격 기준 제품 순위 (상위 10개, 카테고리: 'Laptop')  ===
# 1. MSI Titan GT77 HX, Intel 13th Gen. i9-13980HX, 44CM FHD 144Hz मिनी LED, HDR 1000 गेमिंग लैपटॉप (64GB/4TB NVMe SSD/Windows 11 Home/Nvidia GeForce RTX4090, 16GB GDDR6/कोर काला/3.3kg), 13VI-092IN: 922만 3,139원
# 2. Lenovo ThinkPad T15g Gen 2 20YS002YUS 15.6" टचस्क्रीन नोटबुक - 4K UHD - 3840 x 2160 - Intel Core i9 11th Gen i9-11950H ऑक्टा-कोर (8 कोर) 2.60 GHz - 32 GB RAM - 1 TB SSD - काला: 865만 1,116원
# 3. ASUS ROG Strix निशान 18 (2023) गेमिंग लैपटॉप, 18 "नेबुला डिस्प्ले 16:10 QHD 240Hz/3ms, GeForce RTX 4090, Intel Core i9-13980HX, 32GB DDR5, 2TB PCIe SSD, वाई-फाई 6E, विंडोज 11 प्रो, G834JY-XS97, काला: 837만 8,187원
# 4. ASUS ROG Zephyrus S अल्ट्रा स्लिम गेमिंग लैपटॉप, 15.6 "144Hz IPS-टाइप फुल HD, GeForce RTX 2080, Intel Core i7-8750H CPU, 16GB DDR4, 512GB PCIe Nvme SSD, ऑरा सिंक RGB, विंडोज 10 प्रो - GX531GX-XS74: 742만 4,466원
# 5. Dell Alienware m18 R1 गेमिंग लैपटॉप, Intel Core i9-13980HX प्रोसेसर/64GB/1TB SSD/18.0" (45.72cm) QHD+ FHD 165Hz/NVIDIA RTX 4090 16GB GDDR6/Win 11 + MSO'21/15 महीना McAfee/डार्क मैटेलिक मून/2.72kg: 724만 938원
# 6. MSI CreatorPro Z17, Intel 12th Gen. i7-12700H, 43CM QHD+ 165Hz क्रिएटर लैपटॉप (32GB/1TB NVMe SSD/ Windows 11 Pro/Nvidia RTX A5500 16GB GDDR6/लूनर ग्रे/2.49kg), A12UMST-237IN: 695만 7,766원
# 7. ASUS ROG Zephyrus Duo 16 (2023) ड्युअल स्क्रीन लैपटॉप, 16" (40.64 cm) QHD+ 240Hz/3ms, AMD Ryzen 9 7945HX, 16GB RTX 4090, गेमिंग लैपटॉप (32GB/2TB SSD/Windows 11/ऑफ़िस के साथ, काला/2.67 kg), GX650PY-NM052WS: 679만 5,954원
# 8. MSI CreatorPro Z16 HX, Intel 13th Gen. i9-13950HX, 41CM UHD 120Hz क्रिएटर लैपटॉप (64GB/2TB NVMe SSD/Windows 11 Pro/NVIDIA RTX™ 3000 Ada, GDDR6 8GB/लूनर ग्रे/2.35kg), B13VKTO-214IN: 679만 5,954원
# 9. MSI गेमिंग रेडर GE66, Intel 12th Gen. i7-12700H, 17.3" UHD 120Hz गेमिंग लैपटॉप (16GBx2/2TB NVMe SSD/Windows 11 Home/Nvidia RTX 3080Ti 16GB GDDR 6/ टाइटेनियम ब्लू/2.9kg), 12UHS-218IN,9S7-154414-2-2414-218: 671만 5,048원
# 10. HP ZBook Studio 12th Gen Intel Core i9-12900H 16 इंच (40.6 cm) WQUXGA डिस्प्ले क्रिएटर लैपटॉप 500 nits/32GB RAM/1TB SSD/NVIDIA GeForce RTX 3080 Ti 12GB ग्राफ़िक/Win 11/MSO/B &O/FPR, G9 वर्कस्टेशन PC: 632만 5,469원
